# %% [markdown]
# # Graded Assignment - Melanoma Skin Cancer Detection - CNN Multiclass Classification - Deep Learning

# %% [markdown]
# Author: `Thaker Bhaveshkumar Ajitkumar`<br/>
# Email: `thaker_bhavesh@yahoo.com`<br/>
# Chandigarh University/UpGrad Student ID: `O21MSD16117`

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-statement" data-toc-modified-id="Problem-statement-1">Problem statement</a></span></li><li><span><a href="#Data-Summary" data-toc-modified-id="Data-Summary-2">Data Summary</a></span></li><li><span><a href="#Importing-all-the-important-libraries" data-toc-modified-id="Importing-all-the-important-libraries-3">Importing all the important libraries</a></span></li><li><span><a href="#Importing-Skin-Cancer-Data" data-toc-modified-id="Importing-Skin-Cancer-Data-4">Importing Skin Cancer Data</a></span><ul class="toc-item"><li><span><a href="#Download-Dataset" data-toc-modified-id="Download-Dataset-4.1">Download Dataset</a></span></li><li><span><a href="#Extract-Dataset" data-toc-modified-id="Extract-Dataset-4.2">Extract Dataset</a></span></li><li><span><a href="#Load-using-keras.preprocessing" data-toc-modified-id="Load-using-keras.preprocessing-4.3">Load using keras.preprocessing</a></span></li><li><span><a href="#Create-a-dataset" data-toc-modified-id="Create-a-dataset-4.4">Create a dataset</a></span></li></ul></li><li><span><a href="#Visualize-the-data" data-toc-modified-id="Visualize-the-data-5">Visualize the data</a></span></li><li><span><a href="#Create-and-Compile-the-model" data-toc-modified-id="Create-and-Compile-the-model-6">Create and Compile the model</a></span></li><li><span><a href="#Train-the-model" data-toc-modified-id="Train-the-model-7">Train the model</a></span><ul class="toc-item"><li><span><a href="#Plotting-the-model-performance-(Visualizing-training-results)" data-toc-modified-id="Plotting-the-model-performance-(Visualizing-training-results)-7.1">Plotting the model performance (Visualizing training results)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Key-Observations" data-toc-modified-id="Key-Observations-7.1.0.1">Key Observations</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Image-Augmentation" data-toc-modified-id="Image-Augmentation-8">Image Augmentation</a></span></li><li><span><a href="#Create-the-model-(augmented-images),-and-compile-the-model" data-toc-modified-id="Create-the-model-(augmented-images),-and-compile-the-model-9">Create the model (augmented images), and compile the model</a></span></li><li><span><a href="#Train-the-model-(augmented-images)" data-toc-modified-id="Train-the-model-(augmented-images)-10">Train the model (augmented images)</a></span><ul class="toc-item"><li><span><a href="#Plotting-the-model-performance-(Visualizing-training-results)" data-toc-modified-id="Plotting-the-model-performance-(Visualizing-training-results)-10.1">Plotting the model performance (Visualizing training results)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Key-Observations" data-toc-modified-id="Key-Observations-10.1.0.1">Key Observations</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Find-the-distribution-of-classes-in-the-training-dataset." data-toc-modified-id="Find-the-distribution-of-classes-in-the-training-dataset.-11">Find the distribution of classes in the training dataset.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Key-Observations" data-toc-modified-id="Key-Observations-11.0.0.1">Key Observations</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Rectify-the-class-imbalance" data-toc-modified-id="Rectify-the-class-imbalance-12">Rectify the class imbalance</a></span></li><li><span><a href="#Create-the-model-(with-Augmentor-images),-and-compile-the-model" data-toc-modified-id="Create-the-model-(with-Augmentor-images),-and-compile-the-model-13">Create the model (with Augmentor images), and compile the model</a></span><ul class="toc-item"><li><span><a href="#Create-a-training-dataset" data-toc-modified-id="Create-a-training-dataset-13.1">Create a training dataset</a></span></li><li><span><a href="#Create-a-validation-dataset" data-toc-modified-id="Create-a-validation-dataset-13.2">Create a validation dataset</a></span></li></ul></li><li><span><a href="#Train-the-model-(with-Augmentor-images)" data-toc-modified-id="Train-the-model-(with-Augmentor-images)-14">Train the model (with Augmentor images)</a></span><ul class="toc-item"><li><span><a href="#Plotting-the-model-performance-(Visualizing-training-results)" data-toc-modified-id="Plotting-the-model-performance-(Visualizing-training-results)-14.1">Plotting the model performance (Visualizing training results)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Key-Observations" data-toc-modified-id="Key-Observations-14.1.0.1">Key Observations</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Making-Predictions-on-Test-data" data-toc-modified-id="Making-Predictions-on-Test-data-15">Making Predictions on Test data</a></span><ul class="toc-item"><li><span><a href="#Create-Test-Dataset" data-toc-modified-id="Create-Test-Dataset-15.1">Create Test Dataset</a></span></li><li><span><a href="#Load-model" data-toc-modified-id="Load-model-15.2">Load model</a></span></li><li><span><a href="#Make-predictions" data-toc-modified-id="Make-predictions-15.3">Make predictions</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Problem statement
#
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# ## Data Summary
#
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
# The data set contains the following diseases:
# 1. Actinic keratosis
# 2. Basal cell carcinoma
# 3. Dermatofibroma
# 4. Melanoma
# 5. Nevus
# 6. Pigmented benign keratosis
# 7. Seborrheic keratosis
# 8. Squamous cell carcinoma
# 9. Vascular lesion

# %% [markdown]
# ## Importing all the important libraries

# %%
import sys
import os
import random
import multiprocessing
import warnings
import datetime
import pathlib
import importlib

from zipfile import ZipFile

from glob import glob

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %%
gdown_check = importlib.util.find_spec("gdown")
found = gdown_check is not None
if found:
    import gdown
else:
    # !pip install gdown

    import gdown

# %%
print("python version is............... %s.%s.%s" % sys.version_info[:3])
print("numpy version is................", np.__version__)
print("pandas version is...............", pd.__version__)
print("matplotlib version is...........", mpl.__version__)
print("seaborn version is..............", sns.__version__)
print("gdown version is................", gdown.__version__)
print("tensorflow version is............", tf.__version__)
# Out:
# python version is............... 3.7.13
# numpy version is................ 1.21.6
# pandas version is............... 1.3.5
# matplotlib version is........... 3.2.2
# seaborn version is.............. 0.11.2
# gdown version is................ 4.4.0
# tensorflow version is............ 2.8.0

# %%
mpl_version = float(".".join(mpl.__version__.split(".", 2)[:2]))
if not (mpl_version >= 3.4):
    print(f"matplotlib version {mpl.__version__} is old. please upgrade.")
# Out:
# matplotlib version 3.2.2 is old. please upgrade.

# %%
print(tf.config.list_physical_devices(device_type=None))
print("")
print(
    "GPU is",
    "Available"
    if tf.config.list_physical_devices(device_type="GPU")
    else "NOT AVAILABLE",
)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# GPU is Available

# %%
# %matplotlib inline

warnings.filterwarnings("ignore")

mpl.style.use("ggplot")
plt.style.use("ggplot")
mpl.rc("figure", figsize=(10, 7))
mpl.rcParams["font.family"] = "monospace"

random.seed(123)
np.random.seed(123)
tf.random.set_seed(123)
tf.keras.utils.set_random_seed(123)

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                #value = round(p.get_height(), ndigits=0)
                ax.text(_x, _y, value, ha="center")
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                #value = round(p.get_width(), ndigits=0)
                ax.text(_x, _y, value, ha="center")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %% [markdown]
# ## Importing Skin Cancer Data

# %% [markdown]
# ### Download Dataset

# %%
url = "https://drive.google.com/uc?id=1xLfSQUGDl8ezNNbUkpuHOYvSpTyxVhCs"
output = "CNN_assignment.zip"

if os.path.exists(output):
    print("Zip file already exists")
else:
    print("Downloading the Zip file...")
    gdown.download(url, output, quiet=False, verify=False)
    print("Downloaded the Zip file.")
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1xLfSQUGDl8ezNNbUkpuHOYvSpTyxVhCs
# To: /content/CNN_assignment.zip
# 100%|██████████| 824M/824M [00:17<00:00, 47.5MB/s]
# Downloaded the Zip file.

# %% [markdown]
# ### Extract Dataset

# %%
dir_name = "Skin cancer ISIC The International Skin Imaging Collaboration"

if os.path.exists(dir_name):
    print("Zip file is extracted already")
else:
    print("Extracting the Zip file...")
    with ZipFile(output, "r") as zip:
        zip.extractall()
        zip.close()
        print("Zip file extracted successfully")
# Out:
# Extracting the Zip file...
# Zip file extracted successfully

# %%
root_dir = ""
try:
    from google.colab import drive, files

    root_dir = "/content/" + dir_name
except:
    print("No GOOGLE DRIVE connection. Using local dataset(s).")
    root_dir = dir_name

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
data_dir_train = pathlib.Path(os.path.join(root_dir, "Train"))
data_dir_test = pathlib.Path(os.path.join(root_dir, "Test"))

# %%
image_count_train = len(list(data_dir_train.glob("*/*.jpg")))
print(image_count_train)

image_count_test = len(list(data_dir_test.glob("*/*.jpg")))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ## Visualize the data

# %%
train_files_count = pd.DataFrame(columns=["folder", "total_files"])
count = 0
for root, directories, files in os.walk(data_dir_train):
    if count == 0:
        pass
    else:
        for root1, directories1, files1 in os.walk(root):
            train_files_count = train_files_count.append(
                {"folder": root1.split(sep=os.sep)[-1], "total_files": len(files1)},
                ignore_index=True,
            )
    count += 1

# %%
test_files_count = pd.DataFrame(columns=["folder", "total_files"])
count = 0
for root, directories, files in os.walk(data_dir_test):
    if count == 0:
        pass
    else:
        for root1, directories1, files1 in os.walk(root):
            test_files_count = test_files_count.append(
                {"folder": root1.split(sep=os.sep)[-1], "total_files": len(files1)},
                ignore_index=True,
            )
    count += 1

# %%
plt.subplot(1, 2, 1)
ax = sns.barplot(x=train_files_count["folder"], y=train_files_count["total_files"])
show_values_on_bars(ax)
plt.xticks(rotation=90)
plt.xlabel("Skin Cancer Type")
plt.title("Train Dataset")

plt.subplot(1, 2, 2)
ax = sns.barplot(x=test_files_count["folder"], y=test_files_count["total_files"])
show_values_on_bars(ax)
plt.xticks(rotation=90)
plt.xlabel("Skin Cancer Type")
plt.title("Test Dataset")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    image = plt.imread(str(list(data_dir_train.glob(class_names[i] + "/*.jpg"))[1]))
    plt.imshow(image)
    plt.title(class_names[i])
    plt.axis("off")
plt.tight_layout()

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Create and Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
image_size = 180

# Input Shape
input_shape = (image_size, image_size, 3)

# Kernel Size
kernel_size = (3, 3)

# Activation
activation = tf.nn.relu

# Padding
padding_same = "SAME"
padding_valid = "VALID"

# Pool Size
pool_size = (2, 2)
strides = 2

# Filters
filters_32 = 32
filters_64 = 64
filters_96 = 96
filters_128 = 128
filters_256 = 256
filters_512 = 512

# Drop Outs
dropout=0.25

# Useing same hidden layer size for all hidden layers.
hidden_layer_size = 256

# Set the input and output sizes
n_classes = 9

optimizer = "adam"

# %%
model = tf.keras.models.Sequential()
model.add(
    tf.keras.layers.experimental.preprocessing.Rescaling(
        scale=1.0 / 255.0, input_shape=input_shape
    )
)
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
        input_shape=(180, 180, 32),
    )
)
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation=activation))
model.add(tf.keras.layers.Dropout(dropout))
model.add(tf.keras.layers.Dense(32, activation=activation))
model.add(tf.keras.layers.Dense(n_classes, activation=tf.nn.softmax))

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  dropout (Dropout)           (None, 90, 90, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
# ...

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=True,
)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 32

# Set an early stopping mechanism
early_stopping = tf.keras.callbacks.EarlyStopping(patience=3)
modelcheckpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "base_model_01.h5", save_best_only=True
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    # callbacks=[early_stopping, modelcheckpoint_cb],
    callbacks=[modelcheckpoint_cb],
    # batch_size=batch_size,
)
# Out:
# Epoch 1/40
# 56/56 [==============================] - 28s 111ms/step - loss: 2.0997 - sparse_categorical_accuracy: 0.1925 - val_loss: 2.0833 - val_sparse_categorical_accuracy: 0.2058
# Epoch 2/40
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0483 - sparse_categorical_accuracy: 0.1808 - val_loss: 2.0595 - val_sparse_categorical_accuracy: 0.2058
# Epoch 3/40
# 56/56 [==============================] - 3s 61ms/step - loss: 2.0154 - sparse_categorical_accuracy: 0.2059 - val_loss: 1.9983 - val_sparse_categorical_accuracy: 0.2864
# Epoch 4/40
# 56/56 [==============================] - 3s 61ms/step - loss: 1.9208 - sparse_categorical_accuracy: 0.2846 - val_loss: 1.8191 - val_sparse_categorical_accuracy: 0.3400
# Epoch 5/40
# 56/56 [==============================] - 3s 60ms/step - loss: 1.7961 - sparse_categorical_accuracy: 0.3359 - val_loss: 1.8777 - val_sparse_categorical_accuracy: 0.3065
# Epoch 6/40
# ...

# %% [markdown]
# ### Plotting the model performance (Visualizing training results)

# %%
plt.subplot(1, 2, 1)
plt.plot(history.history["sparse_categorical_accuracy"], label="Train Accuracy")
plt.plot(
    history.history["val_sparse_categorical_accuracy"], label="Validation Accuracy"
)
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train Accuracy", "Validation Accuracy"])

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train Loss", "Validation Loss"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Key Observations
# **Finding on the first base model**
# - The model is overfitting because difference in loss functions in training & validation around 10th epoch
# - The training accuracy is around 75% but validation accuracy is around 50% to 55% only.

# %% [markdown]
# ## Image Augmentation

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
data_augmentation = tf.keras.Sequential()
data_augmentation.add(
    tf.keras.layers.experimental.preprocessing.Rescaling(
        scale=1.0 / 255.0, input_shape=input_shape
    )
)
data_augmentation.add(
    tf.keras.layers.experimental.preprocessing.RandomFlip(
        mode="horizontal_and_vertical"
    )
)
data_augmentation.add(
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2, fill_mode="reflect")
)
data_augmentation.add(
    tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.25)
)
data_augmentation.add(
    tf.keras.layers.experimental.preprocessing.RandomZoom(
        height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode="reflect"
    )
)

data_augmentation.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  random_flip (RandomFlip)    (None, 180, 180, 3)       0
#
#  random_rotation (RandomRota  (None, 180, 180, 3)      0
#  tion)
#
#  random_contrast (RandomCont  (None, 180, 180, 3)      0
#  rast)
#
#  random_zoom (RandomZoom)    (None, 180, 180, 3)       0
#
# ...
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(12, 12))

for images, labels in train_ds.take(9):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(data_augmentation(images)[i].numpy())
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
from PIL import Image

plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    image = Image.open(str(list(data_dir_train.glob(class_names[i] + "/*.jpg"))[1]))
    image=image.resize((image_size,image_size), Image.ANTIALIAS)
    image_array  = tf.keras.preprocessing.image.img_to_array(image)
    image_array=image_array.reshape(1, image_size, image_size, 3)
    plt.imshow(data_augmentation(image_array)[0].numpy())
    plt.title(class_names[i])
    plt.axis("off")
plt.tight_layout()

# %% [markdown]
# ## Create the model (augmented images), and compile the model

# %%
augmented_model = tf.keras.models.Sequential()
augmented_model.add(data_augmentation)
augmented_model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
        input_shape=(180, 180, 32),
    )
)
augmented_model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
augmented_model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
augmented_model.add(tf.keras.layers.Dropout(dropout))
augmented_model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
augmented_model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
augmented_model.add(tf.keras.layers.Dropout(dropout))
augmented_model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
augmented_model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
augmented_model.add(tf.keras.layers.Dropout(dropout))
augmented_model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
augmented_model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
augmented_model.add(tf.keras.layers.Dropout(dropout))

augmented_model.add(tf.keras.layers.Flatten())
augmented_model.add(tf.keras.layers.Dense(64, activation=activation))
augmented_model.add(tf.keras.layers.Dropout(dropout))
augmented_model.add(tf.keras.layers.Dense(32, activation=activation))
augmented_model.add(tf.keras.layers.Dense(n_classes, activation=tf.nn.softmax))

augmented_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# View the summary of all layers
augmented_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
# ...

# %%
tf.keras.utils.plot_model(
    augmented_model,
    to_file="augmented_model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=True,
)

# %% [markdown]
# ## Train the model (augmented images)

# %%
epochs = 40
batch_size = 32

# Set an early stopping mechanism
early_stopping = tf.keras.callbacks.EarlyStopping(patience=3)
modelcheckpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "augmented_model_01.h5", save_best_only=True
)

history = augmented_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    # callbacks=[early_stopping, modelcheckpoint_cb],
    callbacks=[modelcheckpoint_cb],
    # batch_size=batch_size,
)
# Out:
# Epoch 1/40
# 56/56 [==============================] - 6s 70ms/step - loss: 2.1176 - sparse_categorical_accuracy: 0.1881 - val_loss: 2.1104 - val_sparse_categorical_accuracy: 0.2058
# Epoch 2/40
# 56/56 [==============================] - 4s 66ms/step - loss: 2.0584 - sparse_categorical_accuracy: 0.1959 - val_loss: 2.0694 - val_sparse_categorical_accuracy: 0.2058
# Epoch 3/40
# 56/56 [==============================] - 4s 66ms/step - loss: 2.0321 - sparse_categorical_accuracy: 0.1936 - val_loss: 2.0332 - val_sparse_categorical_accuracy: 0.2058
# Epoch 4/40
# 56/56 [==============================] - 4s 65ms/step - loss: 2.0355 - sparse_categorical_accuracy: 0.1981 - val_loss: 2.0412 - val_sparse_categorical_accuracy: 0.2058
# Epoch 5/40
# 56/56 [==============================] - 4s 66ms/step - loss: 2.0106 - sparse_categorical_accuracy: 0.2093 - val_loss: 1.9814 - val_sparse_categorical_accuracy: 0.3154
# Epoch 6/40
# ...

# %% [markdown]
# ### Plotting the model performance (Visualizing training results)

# %%
plt.subplot(1,2,1)
plt.plot(history.history['sparse_categorical_accuracy'], label="Train Accuracy")
plt.plot(history.history['val_sparse_categorical_accuracy'], label="Validation Accuracy")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(["Train Accuracy", "Validation Accuracy"])

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(["Train Loss", "Validation Loss"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Key Observations
# **Finding on the augmented images model**
# - The model is neither overfitting nor underfitting because difference in loss functions in training & validation is minimum.
# - There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation. The training and validation accuracy is nearly same.

# %% [markdown]
# ## Find the distribution of classes in the training dataset.
#
# **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
plt.subplot(1, 2, 1)
ax = sns.barplot(x=train_files_count["folder"], y=train_files_count["total_files"])
show_values_on_bars(ax)
plt.xticks(rotation=90)
plt.xlabel("Skin Cancer Type")
plt.title("Train Dataset")

plt.subplot(1, 2, 2)
ax = sns.barplot(x=test_files_count["folder"], y=test_files_count["total_files"])
show_values_on_bars(ax)
plt.xticks(rotation=90)
plt.xlabel("Skin Cancer Type")
plt.title("Test Dataset")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Key Observations
# + Which class has the least number of samples?
#     - **seborrheic keratosis** has least number of samples.
# + Which classes dominate the data in terms proportionate number of samples?
#     - **pigmented benign keratosis** and **melanoma** have proportionate number of classes.

# %% [markdown]
# ## Rectify the class imbalance
#
# **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
augmentor_check = importlib.util.find_spec("Augmentor")
found = augmentor_check is not None
if found:
    import Augmentor
else:
    # !pip install Augmentor

    import Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
for i in class_names:
    p = Augmentor.Pipeline(
        source_directory=pathlib.Path(os.path.join(data_dir_train, i)),
        #output_directory=pathlib.Path(os.path.join(data_dir_train, i)),
    )
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    ## Other Augmentor Options
    # p.zoom(probability=0.2, min_factor=1.1, max_factor=1.2)
    # p.skew(probability=0.2)
    # p.random_distortion(probability=0.2, grid_width=100, grid_height=100, magnitude=1)
    # p.shear(probability=0.2, max_shear_left=2, max_shear_right=2)
    # p.crop_random(probability=0.2, percentage_area=0.8)
    # p.flip_random(probability=0.2)
    ## We are adding 500 samples per class to make sure that none of the classes are sparse.
    p.sample(500)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F41BB03EB90>: 100%|██████████| 500/500 [00:17<00:00, 27.92 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F41B7BA9AD0>: 100%|██████████| 500/500 [00:19<00:00, 25.39 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F41B6E8D450>: 100%|██████████| 500/500 [00:20<00:00, 24.46 Samples/s]
# Initialised with 438 image(s) found.
# ...

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
train_files_count = pd.DataFrame(columns=["folder", "total_files"])
for filename in os.listdir(data_dir_train):
    for root1, directories1, files1 in os.walk(os.path.join(data_dir_train, filename)):
        if root1.endswith("output"):
            pass
        else:
            for root2, directories2, files2 in os.walk(root1):
                train_files_count = train_files_count.append(
                    {"folder": filename, "total_files": len(files2)},
                    ignore_index=True,
                )
train_files_count = train_files_count.groupby("folder", as_index=False).sum()


ax = sns.barplot(
    x=train_files_count["folder"], y=train_files_count["total_files"], ci=None
)
show_values_on_bars(ax)
plt.xticks(rotation=90)
plt.xlabel("Skin Cancer Type")
plt.title("Train Dataset after Augmentor")
plt.show()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ## Create the model (with Augmentor images), and compile the model

# %%
model = tf.keras.models.Sequential()
model.add(
    tf.keras.layers.experimental.preprocessing.Rescaling(
        scale=1.0 / 255.0, input_shape=input_shape
    )
)
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
        input_shape=(180, 180, 32),
    )
)
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_32,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))
model.add(
    tf.keras.layers.Conv2D(
        filters=filters_64,
        kernel_size=kernel_size,
        padding=padding_same,
        activation=activation,
    )
)
model.add(tf.keras.layers.MaxPool2D(pool_size=pool_size))
model.add(tf.keras.layers.Dropout(dropout))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation=activation))
model.add(tf.keras.layers.Dropout(dropout))
model.add(tf.keras.layers.Dense(32, activation=activation))
model.add(tf.keras.layers.Dense(n_classes, activation=tf.nn.softmax))

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 180, 180, 32)      896
#
#  conv2d_11 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_8 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 90, 90, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 90, 90, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_11 (Dropout)        (None, 45, 45, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 22, 22, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 22, 22, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 11, 11, 64)       0
#  g2D)
#
# ...

# %% [markdown]
# ### Create a training dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ## Train the model (with Augmentor images)

# %%
epochs = 40
batch_size = 32

# Set an early stopping mechanism
early_stopping = tf.keras.callbacks.EarlyStopping(patience=3)
modelcheckpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "augmentor_model_01.h5",
    monitor="val_sparse_categorical_accuracy",
    save_best_only=True,
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    # callbacks=[early_stopping, modelcheckpoint_cb],
    callbacks=[modelcheckpoint_cb],
    # batch_size=batch_size,
)
# Out:
# Epoch 1/40
# 169/169 [==============================] - 42s 238ms/step - loss: 2.0440 - sparse_categorical_accuracy: 0.2062 - val_loss: 1.8055 - val_sparse_categorical_accuracy: 0.2665
# Epoch 2/40
# 169/169 [==============================] - 26s 146ms/step - loss: 1.7461 - sparse_categorical_accuracy: 0.3309 - val_loss: 1.6808 - val_sparse_categorical_accuracy: 0.3422
# Epoch 3/40
# 169/169 [==============================] - 25s 145ms/step - loss: 1.6058 - sparse_categorical_accuracy: 0.3789 - val_loss: 1.5718 - val_sparse_categorical_accuracy: 0.3846
# Epoch 4/40
# 169/169 [==============================] - 26s 150ms/step - loss: 1.5478 - sparse_categorical_accuracy: 0.3999 - val_loss: 1.4215 - val_sparse_categorical_accuracy: 0.4224
# Epoch 5/40
# 169/169 [==============================] - 25s 145ms/step - loss: 1.5121 - sparse_categorical_accuracy: 0.4078 - val_loss: 1.5353 - val_sparse_categorical_accuracy: 0.4091
# Epoch 6/40
# ...

# %% [markdown]
# ### Plotting the model performance (Visualizing training results)

# %%
plt.subplot(1, 2, 1)
plt.plot(history.history["sparse_categorical_accuracy"], label="Train Accuracy")
plt.plot(
    history.history["val_sparse_categorical_accuracy"], label="Validation Accuracy"
)
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train Accuracy", "Validation Accuracy"])

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train Loss", "Validation Loss"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Key Observations
# - Accuracy on training data has increased by using Augmentor library
# - Model is still overfitting
# - Overfitting can be resolved by using addtional layers (BatchNormalization, Dropout) and/or by adding more neurons. Hyperparameter tuning may also require.

# %% [markdown]
# ## Making Predictions on Test data

# %% [markdown]
# ### Create Test Dataset

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
test_class_names = train_ds.class_names
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 118 files belonging to 9 classes.

# %% [markdown]
# ### Load model

# %%
best_model = tf.keras.models.load_model("augmentor_model_01.h5")

# %% [markdown]
# ### Make predictions

# %%
results=best_model.evaluate_generator(test_ds)
print("test loss, test acc:", results)
# Out:
# test loss, test acc: [3.949982166290283, 0.3813559412956238]

# %%
predictions = np.array([], dtype=int)
labels = np.array([], dtype=int)
for x, y in test_ds:
    predictions = np.concatenate([predictions, best_model.predict(x).argmax(axis=1)])
    labels = np.concatenate([labels, y.numpy()])
conf_mat = tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy()

# %%
sns.heatmap(
    conf_mat,
    annot=True,
    # vmin=-1,
    # vmax=1,
    center=0,
    cmap=sns.diverging_palette(240, 10, as_cmap=True),
    square=True,
    linewidths=1.5,
    cbar=False,
    xticklabels=test_class_names,
    yticklabels=test_class_names,
)
plt.show()
